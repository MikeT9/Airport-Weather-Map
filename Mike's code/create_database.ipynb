# %%
# Dependencies
import pandas as pd
import json
import requests
from config import api_key
from config import gkey

# %%
# geocoordinates
# houston 29.76045° N, -95.36978° E
target_coordinates = "29.76045, -95.36978"
target_search = "Airport"
target_radius = 50000
target_type = "airport"

# set up a parameters dictionary
params = {
#    "rectangle": "25.68975, -107.02078|36.72474, -93.40211",
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "ATtYBwIQp7-I-VLN4XEc9D6-VfmW2J5UFyRwpO7gm_SvGW7WSGRDHwVnYr8CxdzhSuDLsARvhhsOsqpUX3pWiZQLTkzzbp5-ZLwgdmZgHSmB7sTdXc_aQRN633SQBHAMlmwdVkvmiR1totTZ3qUbmSXFH5JSUnv49VQLf0YaoXSkwQqDsiNnO3THFfHySukgo3tZLJOX7J3XNJLbKY7_VIoq3GZ2z_C-BPa3xAjgGJqUfPEdGFFNZcQ89btgDXJlYjg2ywmyxas8ezoyj3VOFlQUlGruD5Cll6x57AEo36FyfBgKrm1NmJb_MRtS2T1ckMUbfQUm6tT60c3zq1myg-y0vOIMo4zO-NiVbysa2tsZcTTBmWaES18NJC0BEtd3kxJDx1JKfoGToz59GUwhpUKADOj0-RBpnuPPrh32Rt7pV7RRO26SBQHHo0GdTvEe-BEe7ol_",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.6038999,
#                     "lng": -95.17625869999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.60524667989272,
#                         "lng": -95.17512747010728
#                     },
#                     "southwest": {
#                         "lat": 29.60254702010728,
#                         "lng": -95.17782712989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/airport-71.png",
#             "name": "Ellington Airport",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 718,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111747660252132555861\">Alma Andrea Barahona</a>"
#                     ],
#                     "photo_reference": "ATtYBwJTCNNoYnpz6-Ysjz8nIKR31hL6ZWYVkkZAeRPO78oL4U0-T5QhdWbYbXc9tgTS96L4jCBMvxHSrVCI3ONnAh1tMWPaeNS-IAcZfohtC0LUVaamRcdyCCOwc56m-u-KSCshRTwnOLocX1IS2hlL5y7FjSoOgOSTPvt4KKYxoYc9sklH",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJ9dCiZkWZQIYRisoh02txCoM",
#             "plus_code": {
#                 "compound_code": "JR3F+HF Southbelt / Ellington, Houston, TX",
#                 "global_code": "76X6JR3F+HF"
#             },
#             "rating": 4.9,
#             "reference": "ChIJ9dCiZkWZQIYRisoh02txCoM",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 18,
#             "vicinity": "11602 Aerospace Ave, Houston"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.6691711,
#                     "lng": -95.06431599999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.67141170000002,
#                         "lng": -95.06291407010727
#                     },
#                     "southwest": {
#                         "lat": 29.6624493,
#                         "lng": -95.06561372989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/airport-71.png",
#             "name": "La Porte Municipal Airport",
#             "place_id": "ChIJ290THd6fQIYRI8MTC3JIBEI",
#             "plus_code": {
#                 "compound_code": "MW9P+M7 La Porte, Texas",
#                 "global_code": "76X6MW9P+M7"
#             },
#             "rating": 5,
#             "reference": "ChIJ290THd6fQIYRI8MTC3JIBEI",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 5,
#             "vicinity": "10615 Spencer Hwy, La Porte"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.6459141,
#                     "lng": -95.27689509999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.66348525,
#                         "lng": -95.27580015000001
#                     },
#                     "southwest": {
#                         "lat": 29.64005705,
#                         "lng": -95.27933475
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/airport-71.png",
#             "name": "William P. Hobby Airport (HOU)",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3036,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102219991576106410844\">Viola Aragon</a>"
#                     ],
#                     "photo_reference": "ATtYBwJFge-hqilulahtJdmK1YM4HYDXNsOENrMlRNDOkhqECIT-0dzW_iMP8PB8tbFy21M4L1V-Zzk8ZBD0Dr4JuRnCMg0qysiHKoZXn-qPnhxttNpgB7pMsKLbi5BDX4YetwZ5MQ62d4o3JSRdlZhuhUr8-K_1RoneA_j6djKMu4ZrHo-o",
#                     "width": 4048
#                 }
#             ],
#             "place_id": "ChIJI2ZP70-WQIYRWZj03jmDCJY",
#             "plus_code": {
#                 "compound_code": "JPWF+96 Southeast Houston, Houston, TX",
#                 "global_code": "76X6JPWF+96"
#             },
#             "rating": 4.2,
#             "reference": "ChIJI2ZP70-WQIYRWZj03jmDCJY",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2081,
#             "vicinity": "7800 Airport Blvd, Houston"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.5187123,
#                     "lng": -95.24250239999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.52001947989272,
#                         "lng": -95.24119857010727
#                     },
#                     "southwest": {
#                         "lat": 29.51731982010728,
#                         "lng": -95.24389822989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/airport-71.png",
#             "name": "Pearland Regional Airport",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1908,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115615113973628874019\">Pearland Regional Airport</a>"
#                     ],
#                     "photo_reference": "ATtYBwKRKMf8VfcKkFHTiQ8ikSHIZFcqS-SDap1tU4gUV1OLXuWoZVom9Vr-2z2gDF68aryooedUOHNTTpHqzxpViXWbDgI5hPmL-iC-9a_4YCGtpV8_6I9nIXphZyLYl-_3sUXcngX4OPpMIWp8nc1ULoKcgM0MlaQqHUotweO6vI4JC6p1",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJsaPG9BOQQIYRpkdg3DpdeoE",
#             "plus_code": {
#                 "compound_code": "GQ94+FX Pearland, Texas",
#                 "global_code": "76X6GQ94+FX"
#             },
#             "rating": 4.7,
#             "reference": "ChIJsaPG9BOQQIYRpkdg3DpdeoE",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 49,
#             "vicinity": "17622 Airfield Ln, Pearland"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.7868537,
#                     "lng": -94.95751190000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.78805607989272,
#                         "lng": -94.95628017010728
#                     },
#                     "southwest": {
#                         "lat": 29.78535642010727,
#                         "lng": -94.95897982989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/airport-71.png",
#             "name": "Baytown Airport",
#             "photos": [
#                 {
#                     "height": 1960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104590846773159150598\">Alfredo Enriquez</a>"
#                     ],
#                     "photo_reference": "ATtYBwItU6Z6xwD5J2YEVd9HjYqUQC2PSjXtdlQsnKlbqeMVtAJ4xdabcjQeV8ON6jA1vWecRidwnyku90je0X4KzlGk9HhKv9Hd4uUHrMsq410COogwmOReaYGxuoVU8SkXvZsEgmeye3tHUZE1bK6XlhdlQT9V4xPSrbynaK-RC4bxXZmg",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJW4N2UnRcP4YRwIn4zTXafIM",
#             "plus_code": {
#                 "compound_code": "Q2PR+PX Baytown, Texas",
#                 "global_code": "76X7Q2PR+PX"
#             },
#             "rating": 4.5,
#             "reference": "ChIJW4N2UnRcP4YRwIn4zTXafIM",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 20,
#             "vicinity": "5600 Barkaloo Rd, Baytown"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.3338775,
#                     "lng": -95.1132469
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.33492162989272,
#                         "lng": -95.11221077010727
#                     },
#                     "southwest": {
#                         "lat": 29.33222197010728,
#                         "lng": -95.11491042989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/airport-71.png",
#             "name": "Creasy Airport-5TA5",
#             "place_id": "ChIJJyihEpGAQIYRHO0YweiIwGg",
#             "plus_code": {
#                 "compound_code": "8VMP+HP Santa Fe, Texas",
#                 "global_code": "76X68VMP+HP"
#             },
#             "rating": 0,
#             "reference": "ChIJJyihEpGAQIYRHO0YweiIwGg",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "13222 Vacek St, Santa Fe"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.9902199,
#                     "lng": -95.3367827
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.99599335,
#                         "lng": -95.31230545
#                     },
#                     "southwest": {
#                         "lat": 29.97289955,
#                         "lng": -95.35251084999999
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/airport-71.png",
#             "name": "George Bush Intercontinental/Houston Airport (IAH)",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109011940267492221379\">Carlos Schmilinsky</a>"
#                     ],
#                     "photo_reference": "ATtYBwIqOmJ-UXgmjHH9cMRJwF9JzlnlCYjn__0K4tv4HAy_oznBpA-4DCrc0ZZtYj4IpE6CBtQmjkMWyja4JHmTU2s9IjSl3_0VuT9P9cLqV1v7dSXPtDV6y9ZvXVxr2a4ca2PrR8I4gy71KFXZ1w8s_V5tEM0M8B1Dhak4vkK5JZbvKu_8",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJx1VD2SO0QIYRMcLAyPy0xpw",
#             "plus_code": {
#                 "compound_code": "XMR7+37 Spring, Texas",
#                 "global_code": "76X6XMR7+37"
#             },
#             "rating": 4.2,
#             "reference": "ChIJx1VD2SO0QIYRMcLAyPy0xpw",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 12003,
#             "vicinity": "2800 N Terminal Rd, Houston"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.5052647,
#                     "lng": -95.17664189999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.50624277989272,
#                         "lng": -95.17551977010727
#                     },
#                     "southwest": {
#                         "lat": 29.50354312010728,
#                         "lng": -95.17821942989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/airport-71.png",
#             "name": "Polly Ranch Airport",
#             "place_id": "ChIJv4GpeCybQIYRZe_EbTHcY8Q",
#             "plus_code": {
#                 "compound_code": "GR4F+48 Friendswood, Texas",
#                 "global_code": "76X6GR4F+48"
#             },
#             "rating": 5,
#             "reference": "ChIJv4GpeCybQIYRZe_EbTHcY8Q",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 7,
#             "vicinity": "207 Oak Dr, Friendswood"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.3188472,
#                     "lng": -95.0857611
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.32081407989272,
#                         "lng": -95.08497205
#                     },
#                     "southwest": {
#                         "lat": 29.31811442010728,
#                         "lng": -95.08812825000001
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/airport-71.png",
#             "name": "Old Forker Ultralight Airport",
#             "place_id": "ChIJOV2PLN9_QIYRWXK1TW8a9ho",
#             "plus_code": {
#                 "compound_code": "8W97+GM Santa Fe, Texas",
#                 "global_code": "76X68W97+GM"
#             },
#             "rating": 0,
#             "reference": "ChIJOV2PLN9_QIYRWXK1TW8a9ho",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "Santa Fe"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.5075664,
#                     "lng": -95.4680578
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.50891657989273,
#                         "lng": -95.46668157010727
#                     },
#                     "southwest": {
#                         "lat": 29.50621692010728,
#                         "lng": -95.46938122989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/airport-71.png",
#             "name": "Houston Southwest Airport",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 468,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111865089135152557348\">Houston Southwest Airport</a>"
#                     ],
#                     "photo_reference": "ATtYBwIkmOhUkeN5tqWTlQBcYstxrkq9V7mr7zyyCGgveOOBlpelsDAJ5tI7a4VnzGteezh9eK4hPppIyz9tIkvbsAqt4cy6cn1h7O3UkOXscJoZaQ4q-G0ZPDgB3Pwgi4egu_u81CsF7VnLQLKjnzwrsX07pdHhmBGALtQttXLeYeJ3irMS",
#                     "width": 800
#                 }
#             ],
#             "place_id": "ChIJse2mX-LtQIYRrKMNQf9IiQM",
#             "plus_code": {
#                 "compound_code": "GG5J+2Q Arcola, Texas",
#                 "global_code": "76X6GG5J+2Q"
#             },
#             "rating": 4.6,
#             "reference": "ChIJse2mX-LtQIYRrKMNQf9IiQM",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 27,
#             "vicinity": "503 McKeever Rd, Arcola"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.6272669,
#                     "lng": -95.65288969999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.62862422989272,
#                         "lng": -95.65143317010728
#                     },
#                     "southwest": {
#                         "lat": 29.62592457010727,
#                         "lng": -95.65413282989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/airport-71.png",
#             "name": "Sugar Land Regional Airport",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114225633888942956842\">santhosh kundoor</a>"
#                     ],
#                     "photo_reference": "ATtYBwKAWFIkwJ1J-mL6M-V4eNfI0W9ru_MtXoH1h-qaTENclMvRZUsjwYlqFkyIhGD3iLA-xkid-uFokdyyJ9l9ScoTzPW-r4zMSqz2sjiVjPTcxUSkPoOSLq9ScWYrsIzzCX-0X1h5tcEFaxiSeAMs7Nm2eI_cxkod1VsyjhK4wrmFgU1G",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJdRN1uNDgQIYR9xmkS6ZoZXQ",
#             "plus_code": {
#                 "compound_code": "J8GW+WR Sugar Land, Texas",
#                 "global_code": "76X6J8GW+WR"
#             },
#             "rating": 4.2,
#             "reference": "ChIJdRN1uNDgQIYR9xmkS6ZoZXQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 60,
#             "vicinity": "12888 Hwy 6, Sugar Land"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.8155684,
#                     "lng": -95.6736523
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.81688927989272,
#                         "lng": -95.67185054999999
#                     },
#                     "southwest": {
#                         "lat": 29.81418962010728,
#                         "lng": -95.67905755000001
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/airport-71.png",
#             "name": "West Houston Airport",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110578284710303351811\">J-M F</a>"
#                     ],
#                     "photo_reference": "ATtYBwKF1GpgR2ofxwxEoiz5Ur1Dg8LPqVz_2zwRBJ2q8wNPw3EhB49D93HFECrvmkc6vg3jEStI4_ub0CKR-tmoVVFx2GIq5nAcM0sh06wO6F2im-MIUenjrRqrmEp11CzSlqF4aTptzMl4T5d6WLYLj0Me1wJtp7OZaxC0cSrqQus5rWOf",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJQXjVdJjZQIYR2R5MO-8KSxc",
#             "plus_code": {
#                 "compound_code": "R88G+6G Northwest Houston, Houston, TX",
#                 "global_code": "76X6R88G+6G"
#             },
#             "rating": 4.5,
#             "reference": "ChIJQXjVdJjZQIYR2R5MO-8KSxc",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 82,
#             "vicinity": "18000 Groeschke Rd, Houston"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.7624983,
#                     "lng": -95.47896899999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.76396762989271,
#                         "lng": -95.47772542010728
#                     },
#                     "southwest": {
#                         "lat": 29.76126797010727,
#                         "lng": -95.48042507989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/airport-71.png",
#             "name": "Airport Express Management Ltd",
#             "place_id": "ChIJMeCT4f3DQIYRB5FKkjtFuKU",
#             "plus_code": {
#                 "compound_code": "QG6C+XC Westside, Houston, TX",
#                 "global_code": "76X6QG6C+XC"
#             },
#             "rating": 0,
#             "reference": "ChIJMeCT4f3DQIYRB5FKkjtFuKU",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "651 Bering Dr # 801, Houston"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.0702237,
#                     "lng": -95.5510826
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.07166352989272,
#                         "lng": -95.54973907010728
#                     },
#                     "southwest": {
#                         "lat": 30.06896387010728,
#                         "lng": -95.55243872989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/airport-71.png",
#             "name": "David Wayne Hooks Memorial Airport",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101594900848806116554\">Roger Morales</a>"
#                     ],
#                     "photo_reference": "ATtYBwK_u66EYV_Fl9vOIh2Y4wG9u4ldlCs00sq5afDXrvBM4xcj0Kw6YBKqnoux_1rKPlej09s6BXpDJKrbaCW897NnJwqIr1ygITZk0aCW0hDuQFICNH7_wBN2A8oNwBIDDfzuBygecrgRHgVwnoMZuBpFKHlcXHZlX7xWUXZiXGZq-aPd",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ8cFAf_LAQIYRBKWrULWZ_eM",
#             "plus_code": {
#                 "compound_code": "3CCX+3H Spring, Texas",
#                 "global_code": "86263CCX+3H"
#             },
#             "rating": 4.8,
#             "reference": "ChIJ8cFAf_LAQIYRBKWrULWZ_eM",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 66,
#             "vicinity": "20803 Stuebner Airline Rd, Spring"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.360259,
#                     "lng": -95.0088859
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.36100852989272,
#                         "lng": -95.00789712010727
#                     },
#                     "southwest": {
#                         "lat": 29.35830887010728,
#                         "lng": -95.01059677989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/airport-71.png",
#             "name": "Johnnie Volk Field-37TE",
#             "photos": [
#                 {
#                     "height": 1200,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116982815484791083037\">Charles Smith</a>"
#                     ],
#                     "photo_reference": "ATtYBwLCuQ7OBVplS7w861hZfbENDv_paU5aQ51jA8y8_jtKj5EP-em_eb9NOxiJtI7iV1G27pQNQQZKClH7XE0YtN_q2dCfcPCnhmW-ceEgb51_IujB2GJCfJpv5XM4c_p5hX4ImOimA3Q5VoqbLrKkjYMllvp0hdYU6xsf9t-xDlLv3p43",
#                     "width": 1600
#                 }
#             ],
#             "place_id": "ChIJhcv7cgV_P4YRYFGqJgEP2f0",
#             "plus_code": {
#                 "compound_code": "9X6R+4C Hitchcock, Texas",
#                 "global_code": "76X69X6R+4C"
#             },
#             "rating": 4.7,
#             "reference": "ChIJhcv7cgV_P4YRYFGqJgEP2f0",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "Hitchcock"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.3708711,
#                     "lng": -95.3426984
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.37220412989272,
#                         "lng": -95.34138427010728
#                     },
#                     "southwest": {
#                         "lat": 29.36950447010728,
#                         "lng": -95.34408392989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/airport-71.png",
#             "name": "Songbird Ranch Airport-91TS",
#             "place_id": "ChIJUWMVObCLQIYRSeKPWtPtqZY",
#             "plus_code": {
#                 "compound_code": "9MC4+8W Rosharon, Texas",
#                 "global_code": "76X69MC4+8W"
#             },
#             "rating": 0,
#             "reference": "ChIJUWMVObCLQIYRSeKPWtPtqZY",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "6 Song Bird Dr, Rosharon"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.6556102,
#                     "lng": -95.2779154
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.65697972989271,
#                         "lng": -95.27653732010728
#                     },
#                     "southwest": {
#                         "lat": 29.65428007010727,
#                         "lng": -95.27923697989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/airport-71.png",
#             "name": "Hobby Airport",
#             "photos": [
#                 {
#                     "height": 4160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106287882724591669892\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwIOT40ZGC3QIRoJIFChhOBC9K50sZz5NaXpO7_CtpDhVfA2v0ckDQE4wKLwRX-v2qAgXlz9c3B0ppTrmrSPqzuCe0GgL4afFbZRnQlLvUyv4ONwaV1tar_HkfF-iruuAeABgy6IF1pCW1w5O-Gf-nRtG5mxis5s0wxXulHm65DZ_f0G",
#                     "width": 3120
#                 }
#             ],
#             "place_id": "ChIJBWnCLV-XQIYRAQ8RarUTyaE",
#             "plus_code": {
#                 "compound_code": "MP4C+6R Greater Hobby Area, Houston, TX",
#                 "global_code": "76X6MP4C+6R"
#             },
#             "rating": 4.5,
#             "reference": "ChIJBWnCLV-XQIYRAQ8RarUTyaE",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 919,
#             "vicinity": "Hobby Airport Loop, Houston"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.9871658,
#                     "lng": -95.3378398
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.98851562989272,
#                         "lng": -95.33648997010728
#                     },
#                     "southwest": {
#                         "lat": 29.98581597010728,
#                         "lng": -95.33918962989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/airport-71.png",
#             "name": "George Bush Airport",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117618641904195175079\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwLpwZhBoajPD3eSHDBtwqsIcpWuoFlv21iV4UJeM7MHgBuaBQjl7fnV2iWaSeDheyzIx6DB2rJTedgtnZeQrR7d09qzP_eXxx3BSc3f0OjzhuO8nQX5rncg9nMfXY6M3skFRlDdU5E53_hgfUXA_-meVhqcPyT38Wcoet2OZsRClGxd",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJlwfYRHC1QIYRh3zQJIcPoco",
#             "plus_code": {
#                 "compound_code": "XMP6+VV Spring, Texas",
#                 "global_code": "76X6XMP6+VV"
#             },
#             "rating": 4.4,
#             "reference": "ChIJlwfYRHC1QIYRh3zQJIcPoco",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 415,
#             "vicinity": "Terminal C Arrivals, Houston"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.6873711,
#                     "lng": -95.84028839999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.68873292989272,
#                         "lng": -95.83828992010727
#                     },
#                     "southwest": {
#                         "lat": 29.68603327010728,
#                         "lng": -95.84098957989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/airport-71.png",
#             "name": "Covey Trails Airport-X09",
#             "photos": [
#                 {
#                     "height": 1169,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110369839079642170441\">ChodeOfJustice</a>"
#                     ],
#                     "photo_reference": "ATtYBwLId3oCdjz_RmQ1XuQAXtvutGaxgfN0jCsa5DkuLUE8hBCc5xSRtZeB4N82nnQwY6FBQposkdotn6uJmk30McfEl3yTBm1o9KHzoBcP373WpKyFbKHTfRDs4FDYDKtl8x6naCu--nJxtsP7KjSD37II6Ogby3FCO6UwbwEoDY-e-ssH",
#                     "width": 1991
#                 }
#             ],
#             "place_id": "ChIJrzykEXAeQYYRaegr5GLOW4s",
#             "plus_code": {
#                 "compound_code": "M5P5+WV Richmond, Texas",
#                 "global_code": "76X6M5P5+WV"
#             },
#             "rating": 4,
#             "reference": "ChIJrzykEXAeQYYRaegr5GLOW4s",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 4,
#             "vicinity": "10 Cc, Richmond"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.627137,
#                     "lng": -95.65359409999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.62851937989272,
#                         "lng": -95.65178167010727
#                     },
#                     "southwest": {
#                         "lat": 29.62581972010728,
#                         "lng": -95.65448132989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/airport-71.png",
#             "name": "GlobalSelect at Sugar Land Regional Airport",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1824,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106276896126209961066\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwJvalrKt38GLqwjmGnAXYH8K3OhRx4geI983LTrnrNob-DEqefqPAe30HAQhMdxmRYJ764dn9Zw-s37138Ts_hEVr6D-KjUA8PWF_1Yz0CPVyWV6De-_fM8rwSmuA4OrpWr1WK2sxz6ixIWZlU8LnbFs6uoQE44tscNIttCw5wSYPs",
#                     "width": 2736
#                 }
#             ],
#             "place_id": "ChIJBXhKO9fgQIYRaUdxuuM2IGg",
#             "plus_code": {
#                 "compound_code": "J8GW+VH Sugar Land, Texas",
#                 "global_code": "76X6J8GW+VH"
#             },
#             "rating": 4.8,
#             "reference": "ChIJBXhKO9fgQIYRaUdxuuM2IGg",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 10,
#             "vicinity": "12888 S Texas 6 B, Sugar Land"
#         }
#     ],
#     "status": "OK"
# }

# %%
# Save config information
url = "https://api.openweathermap.org/data/2.5/weather?"
lat = "29.76045"
lon = "-95.36978"
units = "imperial"


# Build query URL
query_url = f"{url}lat={lat}&lon={lon}&units={units}&appid={api_key}"

# %%
# Get weather data
weather_response = requests.get(query_url)
weather_json = weather_response.json()

# Get the temperature from the response
print(json.dumps(weather_json, indent=4, sort_keys=True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 29.7605,
#         "lon": -95.3698
#     },
#     "dt": 1621459570,
#     "id": 4699066,
#     "main": {
#         "feels_like": 69.01,
#         "grnd_level": 1008,
#         "humidity": 53,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 69.84,
#         "temp_max": 72.34,
#         "temp_min": 68.11
#     },
#     "name": "Houston",
#     "rain": {
#         "1h": 1.98
#     },
#     "sys": {
#         "country": "US",
#         "id": 4404,
#         "sunrise": 1621423574,
#         "sunset": 1621472998,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "moderate rain",
#             "icon": "10d",
#             "id": 501,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 116,
#         "gust": 17.87,
#         "speed": 14.45
#     }
# }

# %%
name = []
lat = []
lng = []
for x in places_data["results"]:
    name.append(x["name"])
    lat.append(x["geometry"]["location"]["lat"])
    lng.append(x["geometry"]["location"]["lng"])

# %%
airport_df = pd.DataFrame({
    "name": name,
    "lat": lat,
    "lng": lng,
})
airport_df
# Out:
#                                                  name        lat        lng
# 0                                   Ellington Airport  29.603900 -95.176259
# 1                      William P. Hobby Airport (HOU)  29.645914 -95.276895
# 2                          La Porte Municipal Airport  29.669171 -95.064316
# 3                           Pearland Regional Airport  29.518712 -95.242502
# 4                                     Baytown Airport  29.786854 -94.957512
# 5                                 Creasy Airport-5TA5  29.333877 -95.113247
# 6   George Bush Intercontinental/Houston Airport (...  29.990220 -95.336783
# 7                                 Polly Ranch Airport  29.505265 -95.176642
# 8                       Old Forker Ultralight Airport  29.318847 -95.085761
# 9                           Houston Southwest Airport  29.507566 -95.468058
# 10                        Sugar Land Regional Airport  29.627267 -95.652890
# 11                               West Houston Airport  29.815568 -95.673652
# 12                     Airport Express Management Ltd  29.762498 -95.478969
# 13                 David Wayne Hooks Memorial Airport  30.070224 -95.551083
# 14                        Songbird Ranch Airport-91TS  29.370871 -95.342698
# 15                            Johnnie Volk Field-37TE  29.360259 -95.008886
# 16                                      Hobby Airport  29.655610 -95.277915
# 17        GlobalSelect at Sugar Land Regional Airport  29.627137 -95.653594
# 18                           Covey Trails Airport-X09  29.687371 -95.840288
# 19                                George Bush Airport  29.987166 -95.337840
